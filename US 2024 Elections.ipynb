# %% [markdown]
# # **Sentiment Analysis on 2024 U.S. Election**

# %% [markdown]
# ![Where do Harris and Trump stand on the key election issues_](Where%20do%20Harris%20and%20Trump%20stand%20on%20the%20key%20election%20issues_.jpeg)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Social media has become a powerful platform for political conversation, especially during major events like the 2024 U.S. presidential election. In this project, i analyzed the sentiment of social media mentions to explore how candidates like Kamala Harris, Donald Trump, and others are perceived by the public. By analyzing the tone—whether positive, negative, or neutral—of these mentions, we aim to understand how social media influences voter opinions and amplifies campaign messages. This analysis provides valuable insights into the emotional pulse of the electorate and the role of social media in shaping the election

# %%
train <- read.csv('train.csv')
test <- read.csv('test.csv')
val <- read.csv('test.csv')

View(train)
View(test)
View(val)
# Out:
#     tweet_id user_handle          timestamp
# 1    1       @user123             2024-11-03 08:45:00
# 2    2       @politicsFan         2024-11-03 09:15:23
# 3    3       @greenAdvocate       2024-11-03 10:05:45
# 4    4       @indieVoice          2024-11-03 11:20:10
# 5    5       @libertyLover        2024-11-03 12:35:55
# 6    6       @user456             2024-11-04 08:50:30
# 7    7       @econGuru            2024-11-04 09:25:10
# 8    8       @ecoWarrior          2024-11-04 10:15:20
# 9    9       @neutralNow          2024-11-04 11:45:00
# 10  10       @freedomFirst        2024-11-04 12:55:35
# 11  11       @user789             2024-11-05 08:30:15
# 12  12       @taxTalk             2024-11-05 09:10:50
# 13  13       @sustainability      2024-11-05 10:25:40
# 14  14       @indepThought        2024-11-05 11:35:25
# 15  15       @libertySeek         2024-11-05 12:45:50
# 16  16       @user321             2024-11-06 08:55:05
# 17  17       @businessInsider     2024-11-06 09:20:30
# 18  18       @greenFuture         2024-11-06 10:40:10
# 19  19       @watchingNow         2024-11-06 11:50:45
# 20  20       @freeMarket          2024-11-06 12:30:20
# 21  21       @user654             2024-11-07 08:40:00
# 22  22       @policyMaker         2024-11-07 09:30:25
# 23  23       @ecoSupport          2024-11-07 10:10:35
# 24  24       @neutralThoughts     2024-11-07 11:25:15
# 25  25       @freedomVoice        2024-11-07 12:15:40
# 26  26       @user987             2024-11-08 08:35:20
# 27  27       @marketWatch         2024-11-08 09:05:55
# 28  28       @greenInitiative     2024-11-08 10:20:50
# 29  29       @indieSupport        2024-11-08 11:40:30
# 30  30       @libertyRights       2024-11-08 12:50:10
# ⋮   ⋮        ⋮                    ⋮
# 471 471      @user1063            2024-02-05 08:50:30
# 472 472      @econTalk6           2024-02-05 09:15:55
# 473 473      @greenFutureNow6     2024-02-05 10:05:30
# 474 474      @indiePerspective6   2024-02-05 11:35:25
# 475 475      @libertyMovement12   2024-02-05 12:20:45
# 476 476      @user1064            2024-02-06 08:45:35
# 477 477      @policyDebate11      2024-02-06 09:30:20
# 478 478      @ecoFriendlyLiving7  2024-02-06 10:15:50
# 479 479      @indepThoughts12     2024-02-06 11:25:40
# 480 480      @freedomFighter12    2024-02-06 12:35:30
# 481 481      @user1065            2024-02-07 08:20:55
# 482 482      @taxReform13         2024-02-07 09:10:50
# 483 483      @sustainableFuture13 2024-02-07 10:45:40
# 484 484      @indieChoice13       2024-02-07 11:50:55
# 485 485      @libertyValues13     2024-02-07 12:30:45
# 486 486      @ecoChampion9        2024-02-08 08:30:10
# 487 487      @policyPro9          2024-02-08 09:15:50
# 488 488      @marketMover9        2024-02-08 10:05:35
# 489 489      @indieInsight9       2024-02-08 11:45:25
# 490 490      @libertyVoice10      2024-02-08 12:50:50
# 491 491      @user1066            2024-02-09 08:25:20
# 492 492      @taxWise8            2024-02-09 09:40:55
# 493 493      @greenVision8        2024-02-09 10:30:40
# 494 494      @neutralPulse8       2024-02-09 11:55:15
# 495 495      @freedomAdvocacy8    2024-02-09 12:40:45
# 496 496      @user1067            2024-02-10 08:50:30
# 497 497      @econTalk7           2024-02-10 09:15:55
# 498 498      @greenFutureNow7     2024-02-10 10:05:30
# 499 499      @indiePerspective7   2024-02-10 11:35:25
# 500 500      @libertyMovement13   2024-02-10 12:20:45
#     tweet_text
# 1   Excited to see Kamala Harris leading the Democratic charge!
# 2   Donald Trump's policies are the best for our economy.
# 3   Jill Stein's environmental plans are exactly what we need.
# 4   Robert Kennedy offers a fresh perspective outside the two-party system.
# 5   Chase Oliver's libertarian stance promotes true freedom.
# 6   Kamala Harris has been a strong advocate for healthcare reform.
# 7   Trump's tax policies will benefit small businesses.
# 8   Jill Stein's green initiatives could save our planet.
# 9   Robert Kennedy is running as an independent; interesting choice.
# 10  Chase Oliver promotes minimal government intervention. Love it!
# 11  Kamala Harris is tackling education issues head-on.
# 12  Trump's latest policy could lower taxes for the middle class.
# 13  Jill Stein's renewable energy plans are ambitious.
# 14  Robert Kennedy might disrupt the traditional party dynamics.
# 15  Chase Oliver's views on personal freedom are refreshing.
# 16  Kamala Harris is making strides in criminal justice reform.
# 17  Trump's deregulation efforts are boosting the stock market.
# 18  Jill Stein advocates for sustainable agriculture.
# 19  Robert Kennedy's independent run adds more choices for voters.
# 20  Chase Oliver supports free-market solutions for healthcare.
# 21  Kamala Harris is a strong leader for progressive change.
# 22  Trump's stance on immigration is reshaping national policy.
# 23  Jill Stein's proposals for green jobs are commendable.
# 24  Robert Kennedy's platform as an independent is unclear.
# 25  Chase Oliver emphasizes individual liberties in his campaign.
# 26  Kamala Harris continues to push for affordable housing.
# 27  Trump's economic policies are controversial but effective.
# 28  Jill Stein is focusing on climate change legislation.
# 29  Robert Kennedy offers an alternative to traditional parties.
# 30  Chase Oliver advocates for gun rights and personal freedom.
# ⋮   ⋮
# 471 Kamala Harris is a symbol of progressive leadership.
# 472 Trump's economic strategies are showing mixed results.
# 473 Jill Stein's solar projects are leading the way in renewable energy.
# 474 Robert Kennedy offers pragmatic solutions outside the party lines.
# 475 Chase Oliver is expanding his base among libertarian voters.
# 476 Kamala Harris's foreign policy is earning international acclaim.
# 477 Trump's healthcare policies continue to divide public opinion.
# 478 Jill Stein is pushing for zero-waste initiatives in all major cities.
# 479 Robert Kennedy is committed to bipartisan solutions.
# 480 Chase Oliver advocates for eliminating unnecessary government agencies.
# 481 Kamala Harris's climate initiatives are setting new benchmarks.
# 482 Trump's latest tax reforms are criticized for corporate favoritism.
# 23 Jill Stein     Green Party        75      240   positive
# 24 Robert Kennedy Independent        18       85   neutral
# 25 Chase Oliver   Libertarian Party  40      160   positive
# 26 Kamala Harris  Democratic Party   85      325   positive
# 27 Donald Trump   Republican Party  110      460   negative
# 28 Jill Stein     Green Party        60      215   positive
# 29 Robert Kennedy Independent        25      100   neutral
# 30 Chase Oliver   Libertarian Party  35      140   positive
# 31 Kamala Harris  Democratic Party   90      340   positive
# 32 Donald Trump   Republican Party   95      410   negative
# 33 Jill Stein     Green Party        70      225   positive
# 34 Robert Kennedy Independent        30      115   neutral
# 35 Chase Oliver   Libertarian Party  50      175   positive
# 36 Jill Stein     Green Party        65      220   positive
# 37 Kamala Harris  Democratic Party   80      310   positive
# 38 Donald Trump   Republican Party   90      400   positive
# 39 Robert Kennedy Independent        28      105   neutral
# 40 Chase Oliver   Libertarian Party  50      170   positive
# 41 Kamala Harris  Democratic Party   85      330   positive
# 42 Donald Trump   Republican Party   95      420   positive
# 43 Jill Stein     Green Party        70      230   positive
# 44 Robert Kennedy Independent        22       95   neutral
# 45 Chase Oliver   Libertarian Party  45      150   positive
# 46 Kamala Harris  Democratic Party   95      360   positive
# 47 Donald Trump   Republican Party  100      440   neutral
# 48 Jill Stein     Green Party        75      240   positive
# 49 Robert Kennedy Independent        18       85   neutral
# 50 Chase Oliver   Libertarian Party  40      160   positive

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Before diving into the analysis, I cleaned and preprocessed the data. This involved handling missing values, converting the timestamp column into a proper datetime format, and standardizing the sentiment column into positive, negative, and neutral categories. I also ensured candidate names were consistent. These steps were essential to prepare the data for accurate sentiment analysis.

# %% [markdown]
# **1. Combining the Data**

# %% [markdown]
# The first step in the analysis was to combine the three separate datasets—train, test, and validation—into one comprehensive dataset. This allowed for a unified view of the social media mentions and their associated sentiments. I used the rbind() function in R to merge the datasets, ensuring that all relevant data was included for analysis. This combined dataset served as the foundation for the sentiment analysis.

# %%
combined_data <- rbind(train, val, test)
View(combined_data)
# Out:
#     tweet_id user_handle          timestamp
# 1    1       @user123             2024-11-03 08:45:00
# 2    2       @politicsFan         2024-11-03 09:15:23
# 3    3       @greenAdvocate       2024-11-03 10:05:45
# 4    4       @indieVoice          2024-11-03 11:20:10
# 5    5       @libertyLover        2024-11-03 12:35:55
# 6    6       @user456             2024-11-04 08:50:30
# 7    7       @econGuru            2024-11-04 09:25:10
# 8    8       @ecoWarrior          2024-11-04 10:15:20
# 9    9       @neutralNow          2024-11-04 11:45:00
# 10  10       @freedomFirst        2024-11-04 12:55:35
# 11  11       @user789             2024-11-05 08:30:15
# 12  12       @taxTalk             2024-11-05 09:10:50
# 13  13       @sustainability      2024-11-05 10:25:40
# 14  14       @indepThought        2024-11-05 11:35:25
# 15  15       @libertySeek         2024-11-05 12:45:50
# 16  16       @user321             2024-11-06 08:55:05
# 17  17       @businessInsider     2024-11-06 09:20:30
# 18  18       @greenFuture         2024-11-06 10:40:10
# 19  19       @watchingNow         2024-11-06 11:50:45
# 20  20       @freeMarket          2024-11-06 12:30:20
# 21  21       @user654             2024-11-07 08:40:00
# 19  Robert Kennedy Independent        30      110   neutral
# 20  Chase Oliver   Libertarian Party  40      140   positive
# 21  Kamala Harris  Democratic Party   85      330   positive
# 22  Donald Trump   Republican Party  105      470   negative
# 23  Jill Stein     Green Party        60      210   positive
# 24  Robert Kennedy Independent        20       90   neutral
# 25  Chase Oliver   Libertarian Party  35      130   positive
# 26  Kamala Harris  Democratic Party   75      290   positive
# 27  Donald Trump   Republican Party  115      480   neutral
# 28  Jill Stein     Green Party        70      230   positive
# 29  Robert Kennedy Independent        28      105   neutral
# 30  Chase Oliver   Libertarian Party  50      170   positive
# ⋮   ⋮              ⋮                 ⋮        ⋮     ⋮
# 571 Kamala Harris  Democratic Party   95      360   positive
# 572 Donald Trump   Republican Party  100      440   neutral
# 573 Jill Stein     Green Party        75      240   positive
# 574 Robert Kennedy Independent        18       85   neutral
# 575 Chase Oliver   Libertarian Party  40      160   positive
# 576 Kamala Harris  Democratic Party   85      325   positive
# 577 Donald Trump   Republican Party  110      460   negative
# 578 Jill Stein     Green Party        60      215   positive
# 579 Robert Kennedy Independent        25      100   neutral
# 580 Chase Oliver   Libertarian Party  35      140   positive
# 581 Kamala Harris  Democratic Party   90      340   positive
# 582 Donald Trump   Republican Party   95      410   negative
# 583 Jill Stein     Green Party        70      225   positive
# 584 Robert Kennedy Independent        30      115   neutral
# 585 Chase Oliver   Libertarian Party  50      175   positive
# 586 Jill Stein     Green Party        65      220   positive
# 587 Kamala Harris  Democratic Party   80      310   positive
# 588 Donald Trump   Republican Party   90      400   positive
# 589 Robert Kennedy Independent        28      105   neutral
# 590 Chase Oliver   Libertarian Party  50      170   positive
# 591 Kamala Harris  Democratic Party   85      330   positive
# 592 Donald Trump   Republican Party   95      420   positive
# 593 Jill Stein     Green Party        70      230   positive
# 594 Robert Kennedy Independent        22       95   neutral
# 595 Chase Oliver   Libertarian Party  45      150   positive
# 596 Kamala Harris  Democratic Party   95      360   positive
# 597 Donald Trump   Republican Party  100      440   neutral
# 598 Jill Stein     Green Party        75      240   positive
# 599 Robert Kennedy Independent        18       85   neutral
# 600 Chase Oliver   Libertarian Party  40      160   positive

# %% [markdown]
# **2. Checking for missing values**

# %%
colSums(is.na(combined_data))
# Out:
#    tweet_id user_handle   timestamp  tweet_text   candidate       party
#           0           0           0           0           0           0
#    retweets       likes   sentiment
#           0           0           0

# %% [markdown]
# There were no missing values.

# %% [markdown]
# **3. Checking column data type**

# %%
str(combined_data)

# %% [markdown]
# The time stamp column was formatted as text and therefore it was necessary to change it to datetime format.

# %%
library(lubridate)
combined_data$timestamp <- ymd_hms(combined_data$timestamp)
str(combined_data$timestamp)
# Out:
#  POSIXct[1:600], format: "2024-11-03 08:45:00" "2024-11-03 09:15:23" "2024-11-03 10:05:45" ...

# %% [markdown]
# **4. Checking the distribution of numeric valuables**

# %% [markdown]
# This helped in identifying patterns, outliers, and potential issues that could affect the analysis.

# %%
hist(combined_data$likes, 
     main = "Distribution of Likes", 
     xlab = "Likes", 
     col = "orange", 
     border = "black", 
     breaks = 10)
# Out:
# Plot with title “Distribution of Likes”

# %%
hist(combined_data$retweets, 
     main = "Distribution of Retweets", 
     xlab = "Retweets", 
     col = "purple",
     border = "black",
     breaks = 10)
# Out:
# Plot with title “Distribution of Retweets”

# %% [markdown]
# **5. Text Normalization**

# %% [markdown]
# To prepare the tweets for analysis, text normalization was performed to ensure consistency and reduce noise.

# %%
library(dplyr)
library(tm)

clean_text <- function(text) {
  text <- tolower(text)
  text <- removePunctuation(text)
  text <- removeNumbers(text)
  text <- removeWords(text, stopwords("en"))
  text <- gsub("http\\S+|www\\S+", "", text) # Remove URLs
  return(text)}

combined_data <- combined_data %>%
  mutate(text_cleaned = sapply(tweet_text, clean_text))

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Exploratory Data Analysis (EDA) helps to understand the dataset’s key characteristics. I visualized and summarized key variables to uncover patterns, trends, and potential anomalies. Using tools like histograms and bar plots, EDA provided insights that guided the next steps of the analysis.

# %% [markdown]
# ### Sentiment Distribution

# %% [markdown]
# The Sentiment Distribution step focuses on analyzing how the sentiment of social media posts is spread across different categories—positive, negative, and neutral. By examining the frequency of each sentiment category, I can understand the overall tone of the public’s opinion on the candidates. This analysis helps identify trends and biases in the data, offering valuable insights into how candidates are perceived by the public.

# %%
# Inspecting the sentiment distribution using a bar plot
library(ggplot2)

# Create a bar plot of sentiment distribution
ggplot(combined_data, aes(x = sentiment, fill = sentiment)) +
  geom_bar() +
  labs(title = "Sentiment Distribution", x = "Sentiment", y = "Count") +
  scale_fill_manual(values = c("positive" = "lightgreen", "negative" = "lightcoral", "neutral" = "lightblue")) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **a). Sentiment Distribution by Party**

# %% [markdown]
# By visualizing sentiment for each party, we can understand public perceptions and how they vary among political groups.

# %%
ggplot(combined_data, aes(x = party, fill = sentiment)) +
  geom_bar(position = "dodge") +
  labs(title = "Sentiment by Party", x = "Party", y = "Count") +
  scale_fill_manual(values = c("positive" = "lightgreen", "negative" = "lightcoral", "neutral" = "lightblue")) +
  theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# **b). Sentiment Distribution by Candidate**

# %% [markdown]
# By analyzing the sentiment distribution for each candidate, we can uncover public perceptions and emotional reactions to their campaigns. This analysis provides insights into how different candidates resonate with voters and the tone of discussions surrounding them on social media.

# %%
# Load required libraries
library(ggplot2)

# Create a stacked bar plot for sentiment distribution by candidate
ggplot(combined_data, aes(x = candidate, fill = sentiment)) +
  geom_bar(position = "stack") +
  labs(title = "Sentiment Distribution by Candidate",
       x = "Candidate",
       y = "Count") +
  scale_fill_manual(values = c("positive" = "lightgreen", "neutral" = "lightblue", "negative" = "lightcoral")) +
  theme_minimal() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %% [markdown]
# ## Engagement Analysis

# %% [markdown]
# It’s crucial to examine how the public engages with tweets or likes about candidates and political issues, and whether sentiment influences this engagement. By analyzing the connection between sentiment (positive, negative, or neutral) and engagement metrics, we can uncover which topics or candidates sparked more excitement, debate, or approval among the electorate.

# %% [markdown]
# **a). Average Likes by Sentiment**

# %%
library(dplyr)
library(ggplot2)

# Summarize the engagement (retweets, likes) by sentiment
engagement_analysis <- combined_data %>%
  group_by(sentiment) %>%
  summarize(mean_retweets = mean(retweets, na.rm = TRUE),
            mean_likes = mean(likes, na.rm = TRUE))

# Ensure sentiment is a factor to control the order of bars
engagement_analysis$sentiment <- factor(engagement_analysis$sentiment, levels = c("positive", "neutral", "negative"))

# Visualize the average likes by sentiment
ggplot(engagement_analysis, aes(x = sentiment, y = mean_likes, fill = sentiment)) +
  geom_bar(stat = "identity") +
  labs(title = "Average Likes by Sentiment", x = "Sentiment", y = "Average Likes") +
  theme_minimal()
# Out:
# plot without title

# %% [markdown]
# ## Topic Analysis

# %% [markdown]
# By analyzing the frequency of words and sentiments across different candidates, political parties, and time periods, the goal is to uncover public opinion trends and identify what voters are most concerned about. This analysis will be supported by visualizations such as word clouds, helping to highlight important patterns and topics that emerge in election-related conversations.

# %%
# Ensure the required packages are installed
if (!requireNamespace("wordcloud", quietly = TRUE)) {
  install.packages("wordcloud")
}
if (!requireNamespace("RColorBrewer", quietly = TRUE)) {
  install.packages("RColorBrewer")
}
if (!requireNamespace("dplyr", quietly = TRUE)) {
  install.packages("dplyr")
}

library(wordcloud)
library(RColorBrewer)
library(dplyr)

# Function to generate word cloud
generate_wordcloud <- function(text, title) {
  # Generate word cloud with a reduced number of words
  wordcloud(
    words = text,
    min.freq = 1,
    scale = c(3, 0.5), 
    random.order = FALSE,
    colors = brewer.pal(8, "Dark2"),
    max.words = 100 # Limit the number of words in the cloud
  )
  
  # Add title with smaller font size and without spacing issue
  title(main = title, cex.main = 0.8) 
}

# Generate word clouds for each sentiment
for (sentiment in c("positive", "neutral", "negative")) {
  # Subset the data
  subset <- combined_data %>% filter(sentiment == sentiment)
  
  # Generate the word cloud
  title_text <- paste("Word Cloud for", toupper(substr(sentiment, 1, 1)), substr(sentiment, 2, nchar(sentiment)), "Sentiment")
  generate_wordcloud(subset$tweet_text, title_text)
}
# Out:
# Warning message in tm_map.SimpleCorpus(corpus, tm::removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, function(x) tm::removeWords(x, tm::stopwords())):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, tm::removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, function(x) tm::removeWords(x, tm::stopwords())):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, tm::removePunctuation):
# “transformation drops documents”
# Warning message in tm_map.SimpleCorpus(corpus, function(x) tm::removeWords(x, tm::stopwords())):
# “transformation drops documents”
# Plot with title “Word Cloud for P ositive Sentiment”
# Plot with title “Word Cloud for N eutral Sentiment”
# Plot with title “Word Cloud for N egative Sentiment”

# %% [markdown]
# ## Insights

# %% [markdown]
# **Candidate Sentiment Dynamics**
# . Social media sentiment for Donald Trump displayed significant polarization, with both strongly positive and strongly negative opinions dominating the discussion. Kamala Harris, on the other hand, exhibited a relatively neutral sentiment distribution, indicating less emotionally charged discourse overall.
#
# **Dominant Topics of Discussion**
# . For both candidates, key issues like economic policy and healthcare reform were consistently mentioned.

# %% [markdown]
# ## Limitations

# %% [markdown]
# **Potential Biases in the Dataset**
#
# Demographic Representation: The dataset primarily contains social media mentions, which tend to be more representative of certain demographic groups, such as younger, more tech-savvy individuals. Consequently, the sentiment analysis may not fully capture the views of older populations, rural voters, or those with limited internet access. This skew could influence the overall sentiment trends, especially when considering the impact of social media on different voter segments.
#
# **Limitations of Temporal Data**
#
# The dataset is limited to the time frame in which it was collected, meaning it might not capture shifting sentiments in real-time. If public opinion changes quickly, such as after a controversial statement or event, the dataset may not reflect the most current sentiment. This temporal lag can affect the accuracy of any conclusions drawn from the analysis.
